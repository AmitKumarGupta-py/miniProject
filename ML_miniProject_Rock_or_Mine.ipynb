# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split
import warnings
import matplotlib.py

# %% [markdown]
# * Load DataSet

# %%
sonar = pd.read_csv('sonar_data.csv')

# %%
sonar.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
sonar.columns
# Out:
# Index(['0.0200', '0.0371', '0.0428', '0.0207', '0.0954', '0.0986', '0.1539',
#        '0.1601', '0.3109', '0.2111', '0.1609', '0.1582', '0.2238', '0.0645',
#        '0.0660', '0.2273', '0.3100', '0.2999', '0.5078', '0.4797', '0.5783',
#        '0.5071', '0.4328', '0.5550', '0.6711', '0.6415', '0.7104', '0.8080',
#        '0.6791', '0.3857', '0.1307', '0.2604', '0.5121', '0.7547', '0.8537',
#        '0.8507', '0.6692', '0.6097', '0.4943', '0.2744', '0.0510', '0.2834',
#        '0.2825', '0.4256', '0.2641', '0.1386', '0.1051', '0.1343', '0.0383',
#        '0.0324', '0.0232', '0.0027', '0.0065', '0.0159', '0.0072', '0.0167',
#        '0.0180', '0.0084', '0.0090', '0.0032', 'R'],
#       dtype='object')

# %%
sonar.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %% [markdown]
# * No Null Value

# %%
sonar.isnull().sum().sum()
# Out:
# 0

# %%
sonar['R'].value_counts()
# Out:
# R
# M    111
# R     96
# Name: count, dtype: int64

# %%
sonar.groupby('R').mean()
# Out:
#      0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539  \
# R
# M  0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R  0.022524  0.030232  0.035879  0.041664  0.061680  0.096199  0.113767
#
#      0.1601    0.3109    0.2111  ...    0.0232    0.0027    0.0065    0.0159  \
# R                                ...
# M  0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R  0.117153  0.135584  0.158785  ...  0.012198  0.010533  0.009673  0.009451
#
#      0.0072    0.0167    0.0180    0.0084    0.0090    0.0032
# R
# M  0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R  0.008581  0.007333  0.007708  0.006659  0.007058  0.006053
#
# [2 rows x 60 columns]

# %% [markdown]
# * Target is 'R'

# %%
y = sonar['R']
X = sonar.drop('R', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,shuffle=True,stratify=y)

# %% [markdown]
# ## RandomForestClassifier

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
params = {
    'n_estimators': [200],  # Number of trees in the forest
    'max_depth': [10],       # Maximum depth of trees
    'min_samples_split': [2],   # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1],     # Minimum number of samples required at each leaf node
    'max_features': ['log2'],  # Number of features to consider for the best split
    'criterion': ['entropy'],  # Criterion for splitting nodes
    'bootstrap': [False]         # Whether to use bootstrap samples
}
rf = RandomForestClassifier(random_state=24)
gcv = GridSearchCV(rf, param_grid=params, cv=kfold, scoring='roc_auc',verbose=3)
gcv.fit(X, y)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END bootstrap=False, criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.906 total time=   0.3s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.963 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.967 total time=   0.3s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.947 total time=   0.3s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.945 total time=   0.3s
# ...

# %% [markdown]
# * Best Scores

# %%
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# 0.9455840441023508

# %%
best_m = gcv.best_estimator_
df_imp = pd.DataFrame({'feature':list(X.columns),
              'importance':best_m.feature_importances_ })
df_imp.sort_values('importance', inplace=True)
plt.figure(figsize=(15,15))
plt.barh(df_imp['feature'], df_imp['importance'])
plt.title("Feature Importances Plot for Random Forest")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       2 df_imp = pd.DataFrame({'feature':list(X.columns),
#       3               'importance':best_m.feature_importances_ })
#       4 df_imp.sort_values('importance', inplace=True)
# ----> 5 plt.figure(figsize=(15,15))
#       6 plt.barh(df_imp['feature'], df_imp['importance'])
#       7 plt.title("Feature Importances Plot for Random Forest")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Prediction

# %%
inp_data = (0.053, 0.0885, 0.1997, 0.2604, 0.3225, 0.2247, 0.0617,
            0.2287, 0.095, 0.074, 0.161, 0.2226, 0.2703, 0.3365, 
            0.4266, 0.4144, 0.5655, 0.6921, 0.8547, 0.9234, 0.9171, 
            1, 0.9532, 0.9101, 0.8337, 0.7053, 0.6534, 0.4483, 0.246, 
            0.202, 0.1446, 0.0994, 0.151, 0.2392, 0.4434, 0.5023, 0.4441, 
            0.4571, 0.3927, 0.29, 0.3408, 0.499, 0.3632, 0.1387, 0.18, 0.1299, 
            0.0523, 0.0817, 0.0469, 0.0114, 0.0299, 0.0244, 0.0199, 0.0257, 
            0.0082, 0.0151, 0.0171, 0.0146, 0.0134, 0.0056
)

# Changing to numpy array
inp_data_np = np.asarray(inp_data)

#Reshape the Input data
inp_data_reshape = inp_data_np.reshape(1,-1)

# %%
prediction = best_m.predict(inp_data_reshape)
print(prediction)

# %%
if(prediction[0] == 'R'):
    print('The object is a Rock')
else:
    print('The object is a mine')
